# %%
from langgraph.graph import StateGraph, START, END
from typing import TypedDict
from dotenv import load_dotenv,find_dotenv
from langgraph.checkpoint.memory import InMemorySaver
from langchain_groq import ChatGroq

# %%
load_dotenv(find_dotenv())

llm = ChatGroq(model="openai/gpt-oss-20b", temperature=0)

# %%
class JokeState(TypedDict):

    topic: str
    joke: str
    explanation: str

# %%
def generate_joke(state: JokeState):

    prompt = f'generate a joke on the topic {state["topic"]}'
    response = llm.invoke(prompt).content

    return {'joke': response}

# %%
def generate_explanation(state: JokeState):

    prompt = f'write an explanation for the joke - {state["joke"]}'
    response = llm.invoke(prompt).content

    return {'explanation': response}

# %%
graph = StateGraph(JokeState)

graph.add_node('generate_joke', generate_joke)
graph.add_node('generate_explanation', generate_explanation)

graph.add_edge(START, 'generate_joke')
graph.add_edge('generate_joke', 'generate_explanation')
graph.add_edge('generate_explanation', END)

checkpointer = InMemorySaver()

workflow = graph.compile(checkpointer=checkpointer)

# %%
config1 = {"configurable": {"thread_id": "1"}}
workflow.invoke({'topic':'pizza'}, config=config1)
# Out:
# {'topic': 'pizza',
#  'joke': 'Why did the pizza apply for a job?\n\nBecause it wanted to get a *crust* of a living! 🍕😄',
#  'explanation': '**Explanation of the joke**\n\n> **Why did the pizza apply for a job?  \n>  Because it wanted to get a *crust* of a living! 🍕😄**\n\nThe humor comes from a **word‑play (pun)** that mixes two very different ideas:\n\n| Element | What it normally means | How it’s used in the joke |\n|---------|------------------------|---------------------------|\n| **Pizza “crust”** | The outer, doughy edge of a pizza. | The joke treats the crust as if it were money. |\n| **“Cost of living”** | A common phrase that refers to the amount of money needed to cover basic expenses. | The joke replaces “cost” with “crust,” turning the phrase into “crust of a living.” |\n\nSo the joke is saying that the pizza wants to earn a *crust* (a pun on “cost”) so it can afford to live—just as people need money to pay for their living expenses. The absurd image of a pizza applying for a job adds to the silliness, but the punchline’s humor is all about the double meaning of “crust” versus “cost.”'}

# %%
workflow.get_state(config1)
# Out:
# StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza apply for a job?\n\nBecause it wanted to get a *crust* of a living! 🍕😄', 'explanation': '**Explanation of the joke**\n\n> **Why did the pizza apply for a job?  \n>  Because it wanted to get a *crust* of a living! 🍕😄**\n\nThe humor comes from a **word‑play (pun)** that mixes two very different ideas:\n\n| Element | What it normally means | How it’s used in the joke |\n|---------|------------------------|---------------------------|\n| **Pizza “crust”** | The outer, doughy edge of a pizza. | The joke treats the crust as if it were money. |\n| **“Cost of living”** | A common phrase that refers to the amount of money needed to cover basic expenses. | The joke replaces “cost” with “crust,” turning the phrase into “crust of a living.” |\n\nSo the joke is saying that the pizza wants to earn a *crust* (a pun on “cost”) so it can afford to live—just as people need money to pay for their living expenses. The absurd image of a pizza applying for a job adds to the silliness, but the punchline’s humor is all about the double meaning of “crust” versus “cost.”'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0fdc99-ddaf-63ac-8002-30cad488ece4'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-01-30T10:51:22.711134+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0fdc99-d759-625d-8001-ed4ce5eb8e75'}}, tasks=(), interrupts=())

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza apply for a job?\n\nBecause it wanted to get a *crust* of a living! 🍕😄', 'explanation': '**Explanation of the joke**\n\n> **Why did the pizza apply for a job?  \n>  Because it wanted to get a *crust* of a living! 🍕😄**\n\nThe humor comes from a **word‑play (pun)** that mixes two very different ideas:\n\n| Element | What it normally means | How it’s used in the joke |\n|---------|------------------------|---------------------------|\n| **Pizza “crust”** | The outer, doughy edge of a pizza. | The joke treats the crust as if it were money. |\n| **“Cost of living”** | A common phrase that refers to the amount of money needed to cover basic expenses. | The joke replaces “cost” with “crust,” turning the phrase into “crust of a living.” |\n\nSo the joke is saying that the pizza wants to earn a *crust* (a pun on “cost”) so it can afford to live—just as people need money to pay for their living expenses. The absurd image of a pizza applying for a job adds to the silliness, but the punchline’s humor is all about the double meaning of “crust” versus “cost.”'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0fdc99-ddaf-63ac-8002-30cad488ece4'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-01-30T10:51:22.711134+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0fdc99-d759-625d-8001-ed4ce5eb8e75'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza apply for a job?\n\nBecause it wanted to get a *crust* of a living! 🍕😄'}, next=('generate_explanation',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0fdc99-d759-625d-8001-ed4ce5eb8e75'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-01-30T10:51:22.046729+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0fdc99-d311-6cb1-8000-4da941c4d1a0'}}, tasks=(PregelTask(id='2bf08ee7-15f8-8662-8de4-731545690c14', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': '**Explanation of the joke**\n\n> **Why did the pizza apply for a job?  \n>  Because it wanted to get a *crust* of a living! 🍕😄**\n\nThe humor comes from a **word‑play (pun)** that mixes two very different ideas:\n\n| Element | What it normally means | How it’s used in the joke |\n|---------|------------------------|---------------------------|\n| **Pizza “crust”** | The outer, doughy edge of a pizza. | The joke treats the crust as if it were money. |\n| **“Cost of living”** | A common phrase that refers to the amount of money needed to cover basic expenses. | The joke replaces “cost” with “crust,” turning the phrase into “crust of a living.” |\n\nSo the joke is saying that the pizza wants to earn a *crust* (a pun on “cost”) so it can afford to live—just as people need money to pay for their living expenses. The absurd image of a pizza applying for a job adds to the silliness, but the punchline’s humor is all about the double meaning of “crust” versus “cost.”'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0fdc99-d311-6cb1-8000-4da941c4d1a0'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-01-30T10:51:21.598072+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0fdc99-d30a-66fa-bfff-987468754958'}}, tasks=(PregelTask(id='95ca9660-2dad-c292-308c-7bd171017969', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why did the pizza apply for a job?\n\nBecause it wanted to get a *crust* of a living! 🍕😄'}),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0fdc99-d30a-66fa-bfff-987468754958'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2026-01-30T10:51:21.595058+00:00', parent_config=None, tasks=(PregelTask(id='e9272c5c-3a34-4ca8-f4db-0e9855e57cd2', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'pizza'}),), interrupts=())]

# %%
config2 = {"configurable": {"thread_id": "2"}}
workflow.invoke({'topic':'pasta'}, config=config2)
# Out:
# {'topic': 'pasta',
#  'joke': 'Why did the spaghetti start a band?\n\nBecause it wanted to be a *fettuccine* rockstar—every time it hit a note, it *pasta* the beat!',
#  'explanation': '**Why the joke works – a quick word‑play breakdown**\n\n| Part of the joke | What it’s doing | Why it’s funny |\n|------------------|-----------------|----------------|\n| **“Why did the spaghetti start a band?”** | Sets up a classic “why‑does‑X‑do‑Y” question. | The image of a noodle forming a music group is absurd and immediately grabs attention. |\n| **“Because it wanted to be a *fettuccine* rockstar”** | *Fettuccine* is a type of pasta, but the phrase sounds like “fettuccine rockstar” → “fettuccine” + “rockstar.” | It’s a double‑layer pun: 1) a literal pasta name, 2) a play on “rockstar.” The word “fettuccine” is oddly specific, making the joke feel fresh. |\n| **“—every time it hit a note, it *pasta* the beat!”** | “Pasta” is a noun, but here it’s used as a verb, echoing the phrase “pass the beat.” | The humor comes from turning a food word into a musical verb. It’s a classic “pasta‑verb” joke that turns a mundane word into a punchline. |\n\n### How the layers combine\n\n1. **Absurd premise** – A spaghetti (a noodle) forming a band is already silly.  \n2. **Pasta‑specific wordplay** – Using *fettuccine* (a specific pasta shape) instead of just “pasta” makes the pun sharper.  \n3. **Musical double‑meaning** – “Hit a note” and “beat” are musical terms; swapping “pass” with “pasta” keeps the rhythm while adding a food twist.  \n4. **Sound similarity** – “Fettuccine rockstar” and “pasta the beat” rhyme in rhythm, giving the joke a musical feel that matches the subject.\n\nIn short, the joke is a mash‑up of food and music puns. The humor comes from the absurd image of a noodle wanting to be a rockstar, coupled with clever word substitutions that make the punchline sound like a musical phrase while still being a pasta joke.'}

# %%
workflow.get_state(config1)
# Out:
# StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza apply for a job?\n\nBecause it wanted to get a *crust* of a living! 🍕😄', 'explanation': '**Explanation of the joke**\n\n> **Why did the pizza apply for a job?  \n>  Because it wanted to get a *crust* of a living! 🍕😄**\n\nThe humor comes from a **word‑play (pun)** that mixes two very different ideas:\n\n| Element | What it normally means | How it’s used in the joke |\n|---------|------------------------|---------------------------|\n| **Pizza “crust”** | The outer, doughy edge of a pizza. | The joke treats the crust as if it were money. |\n| **“Cost of living”** | A common phrase that refers to the amount of money needed to cover basic expenses. | The joke replaces “cost” with “crust,” turning the phrase into “crust of a living.” |\n\nSo the joke is saying that the pizza wants to earn a *crust* (a pun on “cost”) so it can afford to live—just as people need money to pay for their living expenses. The absurd image of a pizza applying for a job adds to the silliness, but the punchline’s humor is all about the double meaning of “crust” versus “cost.”'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0fdc99-ddaf-63ac-8002-30cad488ece4'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-01-30T10:51:22.711134+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0fdc99-d759-625d-8001-ed4ce5eb8e75'}}, tasks=(), interrupts=())

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza apply for a job?\n\nBecause it wanted to get a *crust* of a living! 🍕😄', 'explanation': '**Explanation of the joke**\n\n> **Why did the pizza apply for a job?  \n>  Because it wanted to get a *crust* of a living! 🍕😄**\n\nThe humor comes from a **word‑play (pun)** that mixes two very different ideas:\n\n| Element | What it normally means | How it’s used in the joke |\n|---------|------------------------|---------------------------|\n| **Pizza “crust”** | The outer, doughy edge of a pizza. | The joke treats the crust as if it were money. |\n| **“Cost of living”** | A common phrase that refers to the amount of money needed to cover basic expenses. | The joke replaces “cost” with “crust,” turning the phrase into “crust of a living.” |\n\nSo the joke is saying that the pizza wants to earn a *crust* (a pun on “cost”) so it can afford to live—just as people need money to pay for their living expenses. The absurd image of a pizza applying for a job adds to the silliness, but the punchline’s humor is all about the double meaning of “crust” versus “cost.”'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0fdc99-ddaf-63ac-8002-30cad488ece4'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-01-30T10:51:22.711134+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0fdc99-d759-625d-8001-ed4ce5eb8e75'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza apply for a job?\n\nBecause it wanted to get a *crust* of a living! 🍕😄'}, next=('generate_explanation',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0fdc99-d759-625d-8001-ed4ce5eb8e75'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-01-30T10:51:22.046729+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0fdc99-d311-6cb1-8000-4da941c4d1a0'}}, tasks=(PregelTask(id='2bf08ee7-15f8-8662-8de4-731545690c14', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': '**Explanation of the joke**\n\n> **Why did the pizza apply for a job?  \n>  Because it wanted to get a *crust* of a living! 🍕😄**\n\nThe humor comes from a **word‑play (pun)** that mixes two very different ideas:\n\n| Element | What it normally means | How it’s used in the joke |\n|---------|------------------------|---------------------------|\n| **Pizza “crust”** | The outer, doughy edge of a pizza. | The joke treats the crust as if it were money. |\n| **“Cost of living”** | A common phrase that refers to the amount of money needed to cover basic expenses. | The joke replaces “cost” with “crust,” turning the phrase into “crust of a living.” |\n\nSo the joke is saying that the pizza wants to earn a *crust* (a pun on “cost”) so it can afford to live—just as people need money to pay for their living expenses. The absurd image of a pizza applying for a job adds to the silliness, but the punchline’s humor is all about the double meaning of “crust” versus “cost.”'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0fdc99-d311-6cb1-8000-4da941c4d1a0'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-01-30T10:51:21.598072+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0fdc99-d30a-66fa-bfff-987468754958'}}, tasks=(PregelTask(id='95ca9660-2dad-c292-308c-7bd171017969', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why did the pizza apply for a job?\n\nBecause it wanted to get a *crust* of a living! 🍕😄'}),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0fdc99-d30a-66fa-bfff-987468754958'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2026-01-30T10:51:21.595058+00:00', parent_config=None, tasks=(PregelTask(id='e9272c5c-3a34-4ca8-f4db-0e9855e57cd2', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'pizza'}),), interrupts=())]
