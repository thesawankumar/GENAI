# %%
# !pip install -q  langchain-community langchain-openai \
# faiss-cpu tiktoken python-dotenv huggingface-hub
# !pip uninstall -y youtube-transcript-api

# !pip install youtube-transcript-api==0.6.2
# Out:
# Found existing installation: youtube-transcript-api 1.2.3
# Uninstalling youtube-transcript-api-1.2.3:
#   Successfully uninstalled youtube-transcript-api-1.2.3
# Collecting youtube-transcript-api==0.6.2
#   Downloading youtube_transcript_api-0.6.2-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: requests in e:\genai\venv\lib\site-packages (from youtube-transcript-api==0.6.2) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in e:\genai\venv\lib\site-packages (from requests->youtube-transcript-api==0.6.2) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in e:\genai\venv\lib\site-packages (from requests->youtube-transcript-api==0.6.2) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in e:\genai\venv\lib\site-packages (from requests->youtube-transcript-api==0.6.2) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in e:\genai\venv\lib\site-packages (from requests->youtube-transcript-api==0.6.2) (2026.1.4)
# Downloading youtube_transcript_api-0.6.2-py3-none-any.whl (24 kB)
# Installing collected packages: youtube-transcript-api
# Successfully installed youtube-transcript-api-0.6.2
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# from youtube_transcript_api import YouTubeTranscriptApi, TranscriptsDisabled, NoTranscriptFound

from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_community.llms import HuggingFaceHub
from langchain_community.vectorstores import FAISS
from langchain_core.prompts import PromptTemplate

# %%
import youtube_transcript_api
print(youtube_transcript_api.__file__)
# Out:
# e:\GENAI\venv\Lib\site-packages\youtube_transcript_api\__init__.py

# %%
from youtube_transcript_api import YouTubeTranscriptApi, TranscriptsDisabled, NoTranscriptFound

video_id = "Gfr50f6ZBvo"

try:
    transcript_list = YouTubeTranscriptApi.get_transcript(
        video_id,
        languages=["en"]
    )

    transcript = " ".join(chunk["text"] for chunk in transcript_list)
    print(transcript)

except TranscriptsDisabled:
    print("❌ No captions available for this video")

except NoTranscriptFound:
    print("❌ English transcript not found")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 6
#       3 video_id = "Gfr50f6ZBvo"
#       5 try:
# ----> 6     transcript_list = YouTubeTranscriptApi.get_transcript(
#       7         video_id,
#       8         languages=["en"]
#       9     )
#      11     transcript = " ".join(chunk["text"] for chunk in transcript_list)
#      12     print(transcript)
#
# AttributeError: type object 'YouTubeTranscriptApi' has no attribute 'get_transcript'
